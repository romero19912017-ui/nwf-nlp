# %% [markdown]
# # 20 Newsgroups: Incremental NLP with NWF
#
# Train on 3 categories, add sci.med without retraining. k-NN in charge space.

# %%
# %run ../examples/20newsgroups.py

# %% [markdown]
# Or: `python examples/20newsgroups.py --save results/nlp.png`
